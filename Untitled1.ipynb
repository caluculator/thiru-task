# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
path='/content/drive/My Drive/Colab Notebooks/downloads/my_files.xlsx'
my_data = pd.read_excel(path)

# %%
my_data.head(6)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-ceb32c67b8fb> in <cell line: 1>()
# ----> 1 my_data.head(6)
#
# NameError: name 'my_data' is not defined

# %%
my_data.tail(5)
# Out:
#       Order ID Order Date  Order Quantity       Sales       Ship Mode  \
# 1002      7171 2011-02-13              17    303.1865     Regular Air
# 1003      7174 2012-03-10              10    141.9200     Regular Air
# 1004      7175 2010-02-07              10    748.2500  Delivery Truck
# 1005      7203 2009-01-08              25  21752.0100     Regular Air
# 1006      7239 2011-06-29              50   6206.1600     Regular Air
#
#         Profit  Unit Price    Customer Name Customer Segment Product Category
# 1002    92.592       20.99     Andy Gerbode         Consumer       Technology
# 1003    12.200       13.73  Thomas Thornton         Consumer        Furniture
# 1004   -86.990       70.98   Helen Andreada        Corporate        Furniture
# 1005  9296.348      896.99      Ruben Dartt        Corporate  Office Supplies
# 1006  1416.270      120.33    Craig Carroll   Small Business  Office Supplies

# %%
my_data.head()
# Out:
#    Order ID Order Date  Order Quantity      Sales       Ship Mode    Profit  \
# 0         3 2010-10-13               6   261.5400     Regular Air  -213.250
# 1         6 2012-02-20               2     6.9300     Regular Air    -4.640
# 2        32 2011-07-15              26  2808.0800     Regular Air  1054.820
# 3        32 2011-07-15              24  1761.4000  Delivery Truck -1748.560
# 4        32 2011-07-15              23   160.2335     Regular Air   -85.129
#
#    Unit Price       Customer Name Customer Segment Product Category
# 0       38.94  Muhammed MacIntyre   Small Business  Office Supplies
# 1        2.08         Ruben Dartt        Corporate  Office Supplies
# 2      107.53       Liz Pelletier        Corporate        Furniture
# 3       70.89       Liz Pelletier        Corporate        Furniture
# 4        7.99       Liz Pelletier        Corporate       Technology
